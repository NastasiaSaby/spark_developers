# %%
from typing import List
from pyspark.sql import DataFrame
from pyspark.sql.types import StructType, StructField, StringType

data: List = [("Diamant_1A", "TopDiamant"),
    ("Diamant_2B", "Diamants pour toujours"),
    ("Diamant_3C", "Mes diamants préférés"),
    ("Diamant_4D", "Diamants que j'aime"),
    ("Diamant_5E", "TopDiamant")
  ]

schema: StructType = StructType([ \
    StructField("reference", StringType(), True), \
    StructField("marque", StringType(), True),
  ])

dataframe: DataFrame = spark.createDataFrame(data=data,schema=schema)
  
dataframe.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----------------------+
# reference |marque                |
# +----------+----------------------+
# Diamant_1A|TopDiamant            |
# Diamant_2B|Diamants pour toujours|
# Diamant_3C|Mes diamants préférés |
# Diamant_4D|Diamants que j&#39;aime   |
# Diamant_5E|TopDiamant            |
# +----------+----------------------+
#
# </div>

# %%
dataframe.write.mode("overwrite").format("csv").option("path", "/mnt/data/diamants").save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("/mnt/data/diamants")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [FileInfo(path=&#39;dbfs:/mnt/data/diamants/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/_committed_4285950982879127849&#39;, name=&#39;_committed_4285950982879127849&#39;, size=1088),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/_committed_7017878434583578210&#39;, name=&#39;_committed_7017878434583578210&#39;, size=552),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/_committed_vacuum8464085180093677208&#39;, name=&#39;_committed_vacuum8464085180093677208&#39;, size=96),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/_started_4285950982879127849&#39;, name=&#39;_started_4285950982879127849&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/part-00000-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-8-1-c000.csv&#39;, name=&#39;part-00000-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-8-1-c000.csv&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/part-00001-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-9-1-c000.csv&#39;, name=&#39;part-00001-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-9-1-c000.csv&#39;, size=22),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/part-00003-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-11-1-c000.csv&#39;, name=&#39;part-00003-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-11-1-c000.csv&#39;, size=34),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/part-00004-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-12-1-c000.csv&#39;, name=&#39;part-00004-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-12-1-c000.csv&#39;, size=36),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/part-00006-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-14-1-c000.csv&#39;, name=&#39;part-00006-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-14-1-c000.csv&#39;, size=31),
#  FileInfo(path=&#39;dbfs:/mnt/data/diamants/part-00007-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-15-1-c000.csv&#39;, name=&#39;part-00007-tid-4285950982879127849-eaff9631-9cde-4d02-b41d-4315d6541ff6-15-1-c000.csv&#39;, size=22)]</div>

# %%
nouvelle_dataframe = spark.read.option("mode", "failfast").option("path", "/mnt/data/diamants").format("csv").load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
nouvelle_dataframe.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------------------+
#        _c0|                 _c1|
# +----------+--------------------+
# Diamant_3C|Mes diamants préf...|
# Diamant_2B|Diamants pour tou...|
# Diamant_4D| Diamants que j&#39;aime|
# Diamant_1A|          TopDiamant|
# Diamant_5E|          TopDiamant|
# +----------+--------------------+
#
# </div>

# %%
nouvelle_dataframe.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: string (nullable = true)
# -- _c1: string (nullable = true)
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
